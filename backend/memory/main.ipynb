# %%
from openai import OpenAI

from config.settings import settings
from memory.postgres import create_database, close_connection, insert_chat, show_chat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 from openai import OpenAI
#       2
# ----> 3 from config.settings import settings
#       4 from memory.postgres import create_database, close_connection, insert_chat, show_chat
#
# ModuleNotFoundError: No module named 'config'

# %%
openai = OpenAI()

def chat(prompt):
    messages = [{"role": "user", "content": prompt}]

    response = openai.chat.completions.create(
        model="gpt-4.1-nano",
        messages=messages
    )
    # return(response.choices[0].message.content)
    return response
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 openai = OpenAI()
#       2
#       3 def chat(prompt):
#       4     messages = [{"role": "user", "content": prompt}]
#
# File ~/Projects/deployment2/backend/.venv/lib/python3.12/site-packages/openai/_client.py:269, in OpenAI.__init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, provider, base_url, data_residency, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     259 self.admin_api_key = admin_api_key if provider_runtime is None else None
#     261 if (
#     262     provider_runtime is None
#     263     and _enforce_credentials
#    (...)    267     and self.admin_api_key is None
#     268 ):
# --> 269     raise OpenAIError(
#     270         "Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable."
#     271     )
#     273 if organization is None and provider_runtime is None:
#     274     organization = os.environ.get("OPENAI_ORG_ID")
#
# OpenAIError: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.
